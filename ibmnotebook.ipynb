# %%
# Final Project: Introduction to Data Science

## Introduction

This notebook provides an overview of fundamental concepts in data science, including tools, languages, and basic computations.

## Data Science Languages

Some of the most commonly used languages in data science are:

- Python
- R
- SQL
- Java
- Julia
- Scala

## Data Science Libraries

Popular data science libraries include:

- NumPy
- Pandas
- Matplotlib
- Seaborn
- Scikit-learn
- TensorFlow
- PyTorch

## Data Science Tools

| Tool            | Description                          |
|-----------------|--------------------------------------|
| Jupyter Notebook| Interactive computing environment    |
| RStudio         | IDE for R                            |
| Apache Spark    | Big data processing framework        |
| Tableau         | Data visualization tool              |
| VS Code         | Source code editor                   |


## Examples of Arithmetic Expressions in Python

Here are some examples of basic arithmetic operations in Python, such as addition and multiplication.

# This expression multiplies 5 by 4 and then adds 3
result = (5 * 4) + 3
print("The result of (5 * 4) + 3 is:", result)


# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours:.2f} hours.")


## Objectives

The main objectives of this notebook are to:

- Identify popular data science languages and libraries
- List commonly used tools in data science
- Perform basic arithmetic operations using Python
- Demonstrate data science workflow in a Jupyter Notebook


## Author

**Sanjana Shangle**


## GitHub Link

[View my notebook on GitHub](https://github.com/sanjanashangle/IBM-DataScience/ibmnotebook.ipynb)
